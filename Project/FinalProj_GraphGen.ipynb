# %%
import numpy as np
from numpy import r_, exp, cos, sin, pi, zeros, ones, hanning, sqrt, log, floor, reshape, mean
from scipy import signal
from numpy.fft import fft
import matplotlib.pyplot as plt

# %%
# data import by readfile
data_path = 'training/result.txt'
data = np.genfromtxt(data_path, delimiter=' ')
data2_path = 'testing/result.txt'
data2 = np.genfromtxt(data2_path, delimiter=' ')

print(data)
print(data2)
# Out:
# [[2.98625291 0.95604598]
#  [3.1322815  0.95312161]
#  [3.19833134 1.20679673]
#  [4.03028506 0.69921612]]
# [[3.15056515 1.21788612]
#  [1.21628515 3.12360533]
#  [2.93694396 0.89225458]
#  [1.23649053 2.84515751]
#  [3.47387054 0.87777064]
#  [0.31379736 1.18761404]]

# %%
plt.plot(data[:,0],data[:,1])
plt.xlim([0,6])
plt.ylim([0,6])
plt.xlabel('x-location [m]')
plt.ylabel('y-location [m]')
# Out:
# Text(0, 0.5, 'y-location [m]')

# %%
plt.plot(data2[:,0],data2[:,1])
plt.xlim([0,6])
plt.ylim([0,6])
plt.xlabel('x-location [m]')
plt.ylabel('y-location [m]')
# Out:
# Text(0, 0.5, 'y-location [m]')
